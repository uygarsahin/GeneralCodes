# %%
#import pysnc
from pysnc import ServiceNowClient

username = 'JZWXFG@NAM.CORP.GM.COM'
password = '1905GalataS@ray'
proxy_url= ""

#client = pysnc.ServiceNowClient('gm', (username, password),  proxy={'http': proxy_url, 'https': proxy_url}, verify=False)
client = ServiceNowClient('gm', (username, password), verify=False , proxy={'http': proxy_url, 'https': proxy_url} )

# %%
 ##!pip install pysnow --proxy=dcproxy.gm.com:8080

# %%
##!pip install --upgrade pandas --proxy=dcproxy.gm.com:8080

# %%
from pysnc import ServiceNowClient

username = 'JZWXFG@NAM.CORP.GM.COM'
password = '1905GalataS@ray'

client = ServiceNowClient('https://gm.service-now.com', (username, password))

gr = client.GlideRecord('sys_user')
gr.add_query('user_name', 'admin')
gr.query()
for r in gr:
	print(r.sys_id)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: EOF occurred in violation of protocol (_ssl.c:1129)
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# ProxyError: ('Unable to connect to proxy', SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Documents/notebook-python-env/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
# ...

# %%
import pysnow

username = 'JZWXFG@NAM.CORP.GM.COM'
password = '1905GalataS@ray'

s = pysnow.Client(instance='gm',
                  user=username,
                  password=password)

# %%
import requests
import pysnow

username = 'JZWXFG@NAM.CORP.GM.COM'
password = '1905GalataS@ray'

s = requests.Session()
s.verify = False
#s.trust_env = False
s.proxies = { "http":"",  "https": "",}

s.auth = requests.auth.HTTPBasicAuth(username, password)

sn = pysnow.Client(instance='gm', session=s)

# Define a resource, here we'll use the incident table API
incident = sn.resource(api_path='/table/incident')

# Query for incidents with state 3
response = incident.get(query={'state': 3})

# Print out the first match, or `None`
print(response.first_or_none())
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: EOF occurred in violation of protocol (_ssl.c:1129)
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# ProxyError: ('Unable to connect to proxy', SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Documents/notebook-python-env/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
# ...

# %%
curl -vvv -k "https://gm.service-now.com/api/now/account?sysparm_limit=2&sysparm_offset=2>;rel="next"\
--request GET \
--header "Accept:application/json" \
--user 'JZWXFG@NAM.CORP.GM.COM':'1905GalataS@ray'

# %%
import io
my_url = "https://gm.service-now.com/api/now/account?sysparm_limit=2&sysparm_offset=2>"


username = 'JZWXFG@NAM.CORP.GM.COM'
password = '1905GalataS@ray'

s = requests.Session()
s.verify = False
#s.trust_env = False
s.proxies = { "http":"",  "https": "",}

s.auth = requests.auth.HTTPBasicAuth(username, password)
s = requests.get(my_url, proxies=proxies).text

df = pd.read_csv(io.StringIO(s))
